# %%
abc123=25

# %%
abc123
# Out:
# 25

# %%
abc123*2
# Out:
# 50

# %%
print(abc123)
# Out:
# 25

# %%
break=10
# Out:
#   Cell In[6], line 1
#     break=10
#          ^
# SyntaxError: invalid syntax

# %%
Break=10

# %%
break
# Out:
#   Cell In[8], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
print(break)
# Out:
#   Cell In[9], line 1
#     print(break)
#           ^
# SyntaxError: invalid syntax

# %%
print(abc123*2)
# Out:
# 50

# %%
123abc=20
# Out:
#   Cell In[11], line 1
#     123abc=20
#       ^
# SyntaxError: invalid decimal literal

# %%
Val1=12.25

# %%
Val1
# Out:
# 12.25

# %%
Val2=0.05E+2

# %%
Val2
# Out:
# 5.0

# %%
print(Val2)
# Out:
# 5.0

# %%
elif='abc'
# Out:
#   Cell In[17], line 1
#     elif='abc'
#     ^
# SyntaxError: invalid syntax

# %%
Name='Riyan'

# %%
Name
# Out:
# 'Riyan'

# %%
print(Name)
# Out:
# Riyan

# %%
Name*2
# Out:
# 'RiyanRiyan'

# %%
print(Name*2)
# Out:
# RiyanRiyan

# %%
String1="Text"

# %%
print(String1)
# Out:
# Text

# %%
String2="Text \
That is spread across\
Multiple lines"

# %%
String2
# Out:
# 'Text That is spread acrossMultiple lines'

# %%
print(String2)
# Out:
# Text That is spread acrossMultiple lines

# %%
len(String2)
# Out:
# 40

# %%
String3=''' Another
text is also
multiline text'''

# %%
String3
# Out:
# ' Another\ntext is also\nmultiline text'

# %%
print(String3)
# Out:
#  Another
# text is also
# multiline text

# %%
len(String3)
# Out:
# 36

# %%
String4="""Third
Multiline
Text"""

# %%
String4
# Out:
# 'Third\nMultiline\nText'

# %%
print(String4)
# Out:
# Third
# Multiline
# Text

# %%
len(String4)
# Out:
# 20

# %%
String5='''Hi There! \
Python\
Is fun!'''

# %%
String5
# Out:
# 'Hi There! PythonIs fun!'

# %%
print(String5)
# Out:
# Hi There! PythonIs fun!

# %%
len(String5)
# Out:
# 23

# %%
A=None

# %%
A

# %%
print(A)
# Out:
# None

# %%
Chk = True

# %%
Chk
# Out:
# True

# %%
print(Chk)
# Out:
# True
