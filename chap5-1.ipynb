# %%
6*3
# Out:
# 18

# %%
3**3
# Out:
# 27

# %%
6+2*4
# Out:
# 14

# %%
5-3-3
# Out:
# -1

# %%
k=5-(3-3)

# %%
9.0**0.5
# Out:
# 3.0

# %%
(5+3.1)*5
# Out:
# 40.5

# %%
S=5.0-(3-3.0)

# %%
S
# Out:
# 5.0

# %%
12.0/4
# Out:
# 3.0

# %%
7--7--7
# Out:
# 21

# %%
8/6
# Out:
# 1.3333333333333333

# %%
8%3
# Out:
# 2

# %%
3**2**0
# Out:
# 3

# %%
(3**2)**0
# Out:
# 1

# %%
3.0*0.5
# Out:
# 1.5

# %%
9.0%3
# Out:
# 0.0

# %%
-9.0%4
# Out:
# 3.0

# %%
6.2%4
# Out:
# 2.2

# %%
2<5
# Out:
# True

# %%
3<5 and 5>3
# Out:
# True

# %%
4<3 or 6>7
# Out:
# False

# %%
3<=3
# Out:
# True

# %%
4!=5
# Out:
# True

# %%
print("hello","World")
# Out:
# hello World
